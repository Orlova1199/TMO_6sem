# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

data = pd.read_csv('D:\Институт\Семестр_6\ТМО_Гапанюк\лабы\heart.csv', sep=",")
data.head() # Первые 5 строк датасета
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.shape # Размер датасета - 303 строк, 14 колонок
# Out:
# (303, 14)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 303

# %%
data.columns # Список колонок
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.dtypes # Список колонок с типами данных
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
for col in data.columns:
    temp_null_count = data[data[col].isnull()].shape[0] # Количество пустых значений
    print('{} - {}'.format(col, temp_null_count))
# Out:
# age - 0
# sex - 0
# cp - 0
# trestbps - 0
# chol - 0
# fbs - 0
# restecg - 0
# thalach - 0
# exang - 0
# oldpeak - 0
# slope - 0
# ca - 0
# thal - 0
# target - 0

# %%
data.describe() # Основные статистические характеристки набора данных
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data['age'].unique() # Уникальные значения возраста
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77], dtype=int64)

# %%
data['ca'].unique() # Уникальные значения количества сосудов
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
data['sex'].unique() # Уникальные значения для целевого признака
# Out:
# array([1, 0], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(5,5)) 
sns.scatterplot(ax=ax, x='age', y='thalach', data=data)

# %%
fig, ax = plt.subplots(figsize=(5,5)) 
sns.scatterplot(ax=ax, x='age', y='thalach', data=data, hue='exang')

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.distplot(data['chol'])

# %%
sns.jointplot(x='age', y='chol', data=data)

# %%
sns.jointplot(x='age', y='chol', data=data, kind="hex")

# %%
sns.jointplot(x='age', y='chol', data=data, kind="kde")

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue="sex")

# %%
sns.pairplot(data, hue="exang")

# %%
sns.boxplot(x=data['trestbps'])

# %%
sns.boxplot(x='sex', y='thalach', data=data)

# %%
sns.violinplot(x=data['thal'])

# %%
sns.catplot(x='sex', y='thal', data=data, kind="violin", split=True)

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
sns.heatmap(data.corr())

# %%
sns.heatmap(data.corr(), cmap='YlGnBu', annot=True, fmt='.1f')
